# %%
import torch 
import torch.nn as nn

# %%
class Model(nn.Module):
       def __init__ (self,num_features):
              super().__init__()

              self.linear=nn.linear(num_features,1)
              self.sigmoid=nn.Sigmoid()
       def forward(self,features):
              out=self.linear(features)
              out=self.sigmoid(out)
              return out

# %% [markdown]
# Torch info

# %%
#create dataset 
features=torch.rand(10,5)

# %%
features
# Out:
# tensor([[9.4447e-01, 5.5152e-01, 3.0117e-01, 1.4296e-01, 4.4769e-01],
#         [9.1249e-02, 8.7531e-01, 7.9999e-01, 7.4053e-01, 8.0911e-01],
#         [1.8264e-01, 5.2390e-01, 9.6415e-01, 7.1906e-01, 9.6152e-01],
#         [6.2276e-01, 3.5404e-01, 2.4702e-01, 4.2007e-01, 2.0428e-01],
#         [5.7446e-01, 1.9082e-01, 7.4681e-01, 4.2769e-01, 2.4133e-01],
#         [1.3061e-02, 6.0618e-01, 2.8420e-01, 3.0994e-02, 9.6676e-01],
#         [2.7591e-01, 3.3308e-01, 9.6196e-01, 9.6247e-01, 8.3313e-01],
#         [9.6907e-01, 9.2345e-01, 6.2069e-01, 4.1628e-02, 9.2975e-01],
#         [9.5528e-04, 4.1980e-01, 8.3391e-02, 5.8947e-01, 3.4020e-01],
#         [8.4159e-01, 2.5430e-01, 8.8380e-01, 9.1632e-02, 9.9433e-01]])

# %%
features.shape[1]
# Out:
# 5

# %%
model=
