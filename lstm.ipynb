# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import numpy as np 
from collections import Counter 
from torch.utils.data import Dataset, DataLoader
from nltk.tokenize import word_tokenize
import nltk

# %%
document="""Natural language processing (NLP) is a subfield of artificial intelligence that focuses on the interaction 
between computers and humans through natural language. The ultimate goal of NLP is to enable computers to understand, interpret, 
and generate human language in a valuable way. NLP combines computational linguistics with machine learning, deep learning, statistical modeling, 
and more. It has a wide range of applications including language translation, sentiment analysis, chatbots, and information retrieval."""

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/imac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/imac/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# tokenize

# %%
tokens = word_tokenize(document)
print(tokens)
# Out:
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'subfield', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', 'The', 'ultimate', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', 'in', 'a', 'valuable', 'way', '.', 'NLP', 'combines', 'computational', 'linguistics', 'with', 'machine', 'learning', ',', 'deep', 'learning', ',', 'statistical', 'modeling', ',', 'and', 'more', '.', 'It', 'has', 'a', 'wide', 'range', 'of', 'applications', 'including', 'language', 'translation', ',', 'sentiment', 'analysis', ',', 'chatbots', ',', 'and', 'information', 'retrieval', '.']

# %%
build vocabs

# %%
Counter(tokens).keys
# Out:
# Counter({',': 8,
#          'language': 4,
#          'and': 4,
#          '.': 4,
#          'NLP': 3,
#          'a': 3,
#          'of': 3,
#          'is': 2,
#          'computers': 2,
#          'to': 2,
#          'learning': 2,
#          'Natural': 1,
#          'processing': 1,
#          '(': 1,
#          ')': 1,
#          'subfield': 1,
#          'artificial': 1,
#          'intelligence': 1,
#          'that': 1,
#          'focuses': 1,
#          'on': 1,
#          'the': 1,
#          'interaction': 1,
#          'between': 1,
#          'humans': 1,
#          'through': 1,
#          'natural': 1,
#          'The': 1,
#          'ultimate': 1,
#          'goal': 1,
#          'enable': 1,
#          'understand': 1,
#          'interpret': 1,
#          'generate': 1,
#          'human': 1,
#          'in': 1,
#          'valuable': 1,
#          'way': 1,
#          'combines': 1,
#          'computational': 1,
#          'linguistics': 1,
# ...

# %% [markdown]
# build vocab

# %%
vocab={'<UNK>':0}
vocab
# Out:
# {'<UNK>': 0}

# %%
for tokens in Counter(tokens).keys():
    print(tokens)
# Out:
# Natural
# language
# processing
# (
# NLP
# )
# is
# a
# subfield
# of
# artificial
# intelligence
# that
# focuses
# on
# the
# interaction
# between
# computers
# and
# humans
# through
# natural
# .
# The
# ultimate
# goal
# to
# enable
# understand
# ,
# interpret
# generate
# human
# in
# valuable
# way
# combines
# computational
# linguistics
# with
# machine
# learning
# deep
# statistical
# modeling
# more
# It
# has
# wide
# range
# applications
# including
# translation
# sentiment
# analysis
# chatbots
# information
# retrieval

# %%
for tokens in Counter(tokens).keys():
    if tokens not in vocab:
        vocab[tokens]=len(vocab)

# %%
len(vocab)
# Out:
# 2

# %% [markdown]
# extract sentences from data

# %%
input_sentences =document.split('\n')
input_sentences
# Out:
# ['Natural language processing (NLP) is a subfield of artificial intelligence that focuses on the interaction ',
#  'between computers and humans through natural language. The ultimate goal of NLP is to enable computers to understand, interpret, ',
#  'and generate human language in a valuable way. NLP combines computational linguistics with machine learning, deep learning, statistical modeling, ',
#  'and more. It has a wide range of applications including language translation, sentiment analysis, chatbots, and information retrieval.']
